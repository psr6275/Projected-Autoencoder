# %%
from keras.layers import Input, Dense,Dropout, Flatten,Lambda
from keras.models import Model,Sequential
from sklearn.model_selection import train_test_split as tts
from keras.callbacks import TensorBoard
import matplotlib.pyplot as plt
from keras.utils import np_utils,plot_model
from keras.layers.convolutional import Convolution2D,MaxPooling2D,Conv2D
from keras import backend as K
from keras.losses import categorical_hinge,categorical_crossentropy
import tensorflow as tf
# Out:
# Using TensorFlow backend.
# /home/slcf/.pyenv/versions/3.6.2/lib/python3.6/importlib/_bootstrap.py:205: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
from keras.datasets import fashion_mnist as mnist
import numpy as np
(x_train,y_train),(x_test,y_test) = mnist.load_data()

# %%
x_train = x_train.astype('float32')/255.0
x_test = x_test.astype('float32')/255.0
## Make the input image flat
n_features = np.prod(x_train.shape[1:])
xtrain = x_train.reshape((len(x_train),n_features))
xtest = x_test.reshape((len(x_test),n_features))

# %%
### Construct Classifier
X_train = xtrain.reshape(xtrain.shape[0],28,28,1)
Y_train = np_utils.to_categorical(y_train)
X_test = xtest.reshape(xtest.shape[0],28,28,1)
Y_test = np_utils.to_categorical(y_test)
#Y_test = y_test
## in this example, we used sparse cross entropy loss!
num_classes = 10
Xtr, Xval, Ytr, Yval = tts(X_train,Y_train,test_size = 0.3)
#Xtr, Xval, Ytr, Yval = tts(Xtr,Ytr,test_size = 0.3)

# %%
import sys
sys.path.append('../')
from mnist_clf import *
from mnist_dae import *

# %% [markdown]
# # Training Classifier

# %%
mnist_cnn = Mnist_CNN(X_train,Y_train)

# %%
#mnist_cnn.train("../logs/fashion_mnist_CNN_clf.ckpt")
mnist_cnn.restore('../logs/fashion_mnist_CNN_clf.ckpt')
# Out:
# INFO:tensorflow:Restoring parameters from ../logs/fashion_mnist_CNN_clf.ckpt
# Success!

# %%
mnist_cnn.accuracy_score(X_test,Y_test)
# Out:
# 0.88510001

# %%
print(Y_test.shape)
X_test = xtest.reshape(xtest.shape[0],28,28,1)
Y_test = np_utils.to_categorical(y_test)
print(X_test.shape)
# Out:
# (10000, 10)
# (10000, 28, 28, 1)

# %%
_,xtest_n = corrupt(X_test,scale =0.3,noise_type = 'peppSalt')
test_acc = mnist_cnn.sess.run(mnist_cnn.accuracy,feed_dict = {mnist_cnn.eval_imgs:xtest_n,mnist_cnn.labels_eval:Y_test})
print(test_acc)
# Out:
# 0.2557

# %%
n=10
plt.figure(figsize = (20,4))
for i in range(n):
    # Display Original
    ax = plt.subplot(2,n,i+1)
    plt.imshow(xtest_n[i].reshape(28,28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax .get_yaxis().set_visible(False)
    
    # Display Reconstruction
    ax = plt.subplot(2,n,i+1+n)
    plt.imshow(X_test[i].reshape(28,28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

plt.show()

# %% [markdown]
# # Adversarial Attacks (PGD)

# %%
mnist_cnn.targeted_attack(X_test,Y_test,file_name = 'minstF_adv')
# Out:
# [0/10000] processed
# [100/10000] processed
# [200/10000] processed
# [300/10000] processed
# [400/10000] processed
# [500/10000] processed
# [600/10000] processed
# [700/10000] processed
# [800/10000] processed
# [900/10000] processed
# [1000/10000] processed
# [1100/10000] processed
# [1200/10000] processed
# [1300/10000] processed
# [1400/10000] processed
# [1500/10000] processed
# [1600/10000] processed
# [1700/10000] processed
# [1800/10000] processed
# [1900/10000] processed
# [2000/10000] processed
# [2100/10000] processed
# [2200/10000] processed
# [2300/10000] processed
# [2400/10000] processed
# [2500/10000] processed
# [2600/10000] processed
# [2700/10000] processed
# [2800/10000] processed
# [2900/10000] processed
# [3000/10000] processed
# [3100/10000] processed
# [3200/10000] processed
# [3300/10000] processed
# [3400/10000] processed
# [3500/10000] processed
# [3600/10000] processed
# [3700/10000] processed
# [3800/10000] processed
# [3900/10000] processed
# [4000/10000] processed
# [4100/10000] processed
# [4200/10000] processed
# [4300/10000] processed
# [4400/10000] processed
# [4500/10000] processed
# [4600/10000] processed
# [4700/10000] processed
# [4800/10000] processed
# [4900/10000] processed
# [5000/10000] processed
# [5100/10000] processed
# [5200/10000] processed
# [5300/10000] processed
# [5400/10000] processed
# [5500/10000] processed
# [5600/10000] processed
# [5700/10000] processed
# [5800/10000] processed
# [5900/10000] processed
# [6000/10000] processed
# [6100/10000] processed
# [6200/10000] processed
# [6300/10000] processed
# [6400/10000] processed
# [6500/10000] processed
# [6600/10000] processed
# [6700/10000] processed
# [6800/10000] processed
# [6900/10000] processed
# [7000/10000] processed
# [7100/10000] processed
# [7200/10000] processed
# [7300/10000] processed
# [7400/10000] processed
# [7500/10000] processed
# [7600/10000] processed
# [7700/10000] processed
# [7800/10000] processed
# [7900/10000] processed
# [8000/10000] processed
# [8100/10000] processed
# [8200/10000] processed
# [8300/10000] processed
# [8400/10000] processed
# [8500/10000] processed
# [8600/10000] processed
# [8700/10000] processed
# [8800/10000] processed
# [8900/10000] processed
# [9000/10000] processed
# [9100/10000] processed
# [9200/10000] processed
# [9300/10000] processed
# [9400/10000] processed
# [9500/10000] processed
# [9600/10000] processed
# [9700/10000] processed
# [9800/10000] processed
# [9900/10000] processed
# ------------------------------------------------------------------
# NameError                        Traceback (most recent call last)
# <ipython-input-25-aa71843d474b> in <module>()
# ----> 1 mnist_cnn.targeted_attack(X_test,Y_test,file_name = 'minstF_adv')
#
# ~/saerom/PAE/mnist_clf.py in targeted_attack(self, testX, testY, alpha, max_iter, eps, file_name)
#     160         self.advX = np.array(adv_list)
#     161         if file_name is not None:
# --> 162             np.save(self.save_path+file_name,advX)
#     163
#     164     def save_np(self,np_array,file_name):
#
# NameError: name 'advX' is not defined

# %%
print(mnist_cnn.accuracy_score(mnist_cnn.advX,Y_test))
print(mnist_cnn.accuracy_score(mnist_cnn.advX,mnist_cnn.advY))
# Out:
# 0.232
# 0.7118

# %%
n=10
plt.figure(figsize = (20,4))
for i in range(n):
    # Display Original
    ax = plt.subplot(2,n,i+1)
    plt.imshow(mnist_cnn.advX[i].reshape(28,28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax .get_yaxis().set_visible(False)
    
    # Display Reconstruction
    ax = plt.subplot(2,n,i+1+n)
    plt.imshow(X_test[i].reshape(28,28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

plt.show()

# %% [markdown]
# # Training Denoising Autoencoder

# %%
encoder, decoder, autoencoder = mnist_dae()

# %%
autoencoder.compile(optimizer = 'adadelta',loss='binary_crossentropy')

# %%
## Generate noised images
noise_scale = 0.3
xtrain_o,xtrain_n = corrupt(xtrain,scale = noise_scale)

# %%
xtrain_t = np.concatenate([xtrain_o,xtrain_n],axis =1)
print(xtrain_t.shape)
dmm = np.ones(shape = (len(xtrain_t),))
xtr,xval,_,_ = tts(xtrain_t,dmm,test_size = 0.3)
xtr_o = xtr[:,:n_features]
xtr_n = xtr[:,n_features:]
xval_o = xval[:,:n_features]
xval_n = xval[:,n_features:]
# Out:
# (60000, 1568)

# %%
## Training the model
print("noise_scale: ",noise_scale)
autoencoder.fit(xtr_n,xtr_o,
               epochs = 50,
               batch_size = 128,
               shuffle=True,
               validation_data=(xval_n,xval_o),
               callbacks = [TensorBoard(log_dir = '../logs/mnist_denseDAE', histogram_freq=0,write_graph=False)]
                )
# Out:
# noise_scale:  0.3
# Train on 42000 samples, validate on 18000 samples
# Epoch 1/50
# 42000/42000 [==============================] - 4s 88us/step - loss: 0.3976 - val_loss: 0.3405
# Epoch 2/50
# 42000/42000 [==============================] - 4s 89us/step - loss: 0.3264 - val_loss: 0.3197
# Epoch 3/50
# 42000/42000 [==============================] - 4s 91us/step - loss: 0.3149 - val_loss: 0.3145
# Epoch 4/50
# 42000/42000 [==============================] - 4s 91us/step - loss: 0.3094 - val_loss: 0.3124
# Epoch 5/50
# 42000/42000 [==============================] - 4s 90us/step - loss: 0.3054 - val_loss: 0.3082
# Epoch 6/50
# 42000/42000 [==============================] - 4s 91us/step - loss: 0.3021 - val_loss: 0.3040
# Epoch 7/50
# 42000/42000 [==============================] - 4s 92us/step - loss: 0.2997 - val_loss: 0.3005
# Epoch 8/50
# 42000/42000 [==============================] - 4s 90us/step - loss: 0.2974 - val_loss: 0.2986
# Epoch 9/50
# 42000/42000 [==============================] - 4s 86us/step - loss: 0.2954 - val_loss: 0.2977
# Epoch 10/50
# 42000/42000 [==============================] - 4s 84us/step - loss: 0.2939 - val_loss: 0.2964
# Epoch 11/50
# 42000/42000 [==============================] - 4s 90us/step - loss: 0.2923 - val_loss: 0.2937
# Epoch 12/50
# 42000/42000 [==============================] - 4s 90us/step - loss: 0.2912 - val_loss: 0.2939
# Epoch 13/50
# 42000/42000 [==============================] - 4s 90us/step - loss: 0.2900 - val_loss: 0.2934
# Epoch 14/50
# 42000/42000 [==============================] - 4s 90us/step - loss: 0.2890 - val_loss: 0.2909
# Epoch 15/50
# 42000/42000 [==============================] - 4s 90us/step - loss: 0.2882 - val_loss: 0.2907
# Epoch 16/50
# 42000/42000 [==============================] - 4s 88us/step - loss: 0.2874 - val_loss: 0.2906
# Epoch 17/50
# 42000/42000 [==============================] - 4s 90us/step - loss: 0.2867 - val_loss: 0.2897
# Epoch 18/50
# 42000/42000 [==============================] - 4s 89us/step - loss: 0.2861 - val_loss: 0.2894
# Epoch 19/50
# 42000/42000 [==============================] - 4s 90us/step - loss: 0.2856 - val_loss: 0.2885
# Epoch 20/50
# 42000/42000 [==============================] - 4s 90us/step - loss: 0.2849 - val_loss: 0.2882
# Epoch 21/50
# 42000/42000 [==============================] - 4s 88us/step - loss: 0.2844 - val_loss: 0.2872
# Epoch 22/50
# 42000/42000 [==============================] - 4s 90us/step - loss: 0.2840 - val_loss: 0.2871
# Epoch 23/50
# 42000/42000 [==============================] - 4s 90us/step - loss: 0.2835 - val_loss: 0.2866
# Epoch 24/50
# 42000/42000 [==============================] - 4s 89us/step - loss: 0.2831 - val_loss: 0.2862
# Epoch 25/50
# 42000/42000 [==============================] - 4s 89us/step - loss: 0.2827 - val_loss: 0.2867
# Epoch 26/50
# 42000/42000 [==============================] - 4s 90us/step - loss: 0.2823 - val_loss: 0.2864
# Epoch 27/50
# 42000/42000 [==============================] - 4s 90us/step - loss: 0.2820 - val_loss: 0.2846
# Epoch 28/50
# 42000/42000 [==============================] - 4s 90us/step - loss: 0.2816 - val_loss: 0.2867
# Epoch 29/50
# 42000/42000 [==============================] - 4s 89us/step - loss: 0.2814 - val_loss: 0.2856
# Epoch 30/50
# 42000/42000 [==============================] - 4s 89us/step - loss: 0.2811 - val_loss: 0.2845
# Epoch 31/50
# 42000/42000 [==============================] - 4s 89us/step - loss: 0.2808 - val_loss: 0.2843
# Epoch 32/50
# 42000/42000 [==============================] - 4s 89us/step - loss: 0.2805 - val_loss: 0.2835
# Epoch 33/50
# 42000/42000 [==============================] - 4s 88us/step - loss: 0.2802 - val_loss: 0.2841
# Epoch 34/50
# 42000/42000 [==============================] - 4s 90us/step - loss: 0.2800 - val_loss: 0.2826
# Epoch 35/50
# 42000/42000 [==============================] - 4s 89us/step - loss: 0.2797 - val_loss: 0.2826
# Epoch 36/50
# 42000/42000 [==============================] - 4s 89us/step - loss: 0.2795 - val_loss: 0.2835
# Epoch 37/50
# 42000/42000 [==============================] - 4s 89us/step - loss: 0.2793 - val_loss: 0.2822
# Epoch 38/50
# 42000/42000 [==============================] - 4s 89us/step - loss: 0.2791 - val_loss: 0.2824
# Epoch 39/50
# 42000/42000 [==============================] - 4s 90us/step - loss: 0.2788 - val_loss: 0.2843
# Epoch 40/50
# 42000/42000 [==============================] - 4s 88us/step - loss: 0.2786 - val_loss: 0.2823
# Epoch 41/50
# 42000/42000 [==============================] - 4s 89us/step - loss: 0.2785 - val_loss: 0.2814
# Epoch 42/50
# 42000/42000 [==============================] - 4s 90us/step - loss: 0.2783 - val_loss: 0.2820
# Epoch 43/50
# 42000/42000 [==============================] - 4s 89us/step - loss: 0.2781 - val_loss: 0.2809
# Epoch 44/50
# 42000/42000 [==============================] - 4s 89us/step - loss: 0.2779 - val_loss: 0.2808
# Epoch 45/50
# 42000/42000 [==============================] - 4s 89us/step - loss: 0.2778 - val_loss: 0.2812
# Epoch 46/50
# 42000/42000 [==============================] - 4s 89us/step - loss: 0.2776 - val_loss: 0.2813
# Epoch 47/50
# 42000/42000 [==============================] - 4s 88us/step - loss: 0.2774 - val_loss: 0.2810
# Epoch 48/50
# 42000/42000 [==============================] - 4s 89us/step - loss: 0.2772 - val_loss: 0.2804
# Epoch 49/50
# 42000/42000 [==============================] - 4s 89us/step - loss: 0.2771 - val_loss: 0.2816
# Epoch 50/50
# 42000/42000 [==============================] - 4s 86us/step - loss: 0.2770 - val_loss: 0.2802

# %%
xtest_o,xtest_n = corrupt(xtest,scale =0.3,noise_type='peppSalt')
decoded_imgs = autoencoder.predict(xtest_n)

n=10
plt.figure(figsize = (20,4))
for i in range(n):
    # Display Original
    ax = plt.subplot(2,n,i+1)
    plt.imshow(xtest_n[i].reshape(28,28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax .get_yaxis().set_visible(False)
    
    # Display Reconstruction
    ax = plt.subplot(2,n,i+1+n)
    plt.imshow(decoded_imgs[i].reshape(28,28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

plt.show()

# %%
print(xtest_n.shape)
# Out:
# (10000, 784)

# %%
mnist_cnn.accuracy_score(xtest_n.reshape(-1,28,28,1),Y_test)
# Out:
# 0.25139999

# %%
mnist_cnn.accuracy_score(decoded_imgs.reshape(-1,28,28,1),Y_test)
# Out:
# 0.76840001

# %%
print(mnist_cnn.advX.shape)
# Out:
# (10000, 28, 28, 1)

# %%
decoded_advX = autoencoder.predict(mnist_cnn.advX.reshape(-1,784))

# %%
mnist_cnn.accuracy_score(decoded_advX.reshape(-1,28,28,1),Y_test)
# Out:
# 0.76169997

# %%
mnist_cnn.accuracy_score(decoded_advX.reshape(-1,28,28,1),mnist_cnn.advY)
# Out:
# 0.093000002

# %% [markdown]
# # Applying DS to noised data

# %%
from mnist_ds import *

# %%
xx = projection_DS(autoencoder,xtest_n[0].reshape(-1,784),viz_image=100 )
