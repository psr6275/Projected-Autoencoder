# %%
from keras.layers import Input, Dense,Dropout, Flatten,Lambda
from keras.models import Model,Sequential
from sklearn.model_selection import train_test_split as tts
from keras.callbacks import TensorBoard
import matplotlib.pyplot as plt
from keras.utils import np_utils,plot_model
from keras.layers.convolutional import Convolution2D,MaxPooling2D,Conv2D
from keras import backend as K
from keras.losses import categorical_hinge,categorical_crossentropy
import tensorflow as tf
#from tensorflow.layers import flatten,batch_normialization as batch_norm
# Out:
# Using TensorFlow backend.
# /home/slcf/.pyenv/versions/3.6.2/lib/python3.6/importlib/_bootstrap.py:205: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %% [markdown]
# ## load data

# %%
from keras.datasets import cifar10
(x_train,y_train),(x_test,y_test) = cifar10.load_data()

# %%
x_train = x_train.astype('float32')/255.0
x_test = x_test.astype('float32')/255.0
Y_train = np_utils.to_categorical(y_train)
Y_test = np_utils.to_categorical(y_test)

# %%
print(x_train.shape)
# Out:
# (50000, 32, 32, 3)

# %%
Xtr,Xval,Ytr,Yval = tts(x_train,Y_train,test_size = 0.3)

# %% [markdown]
# ## import defined modules

# %%
import sys
sys.path.append('../')
from cifar_clf import *
from cifar_tfdae import *

# %%
cifar_cnn = Cifar10_CNN(x_train,Y_train,num_batch=128,num_epoch=50)

# %%
print(Xtr.shape)
# Out:
# (35000, 32, 32, 3)

# %%
#len(cifar_cnn.batch_gen.get_batch())

# %% [markdown]
# ### train classifer

# %%
#cifar_cnn.train("cifar_CNN_clf.ckpt")
cifar_cnn.restore("cifar_CNN_clf.ckpt")
# Out:
# [0/5850] Loss: 2.293516 Train_Acc: 0.1172 Val_Acc: 0.0703
# [500/5850] Loss: 0.958169 Train_Acc: 0.7188 Val_Acc: 0.5469
# [1000/5850] Loss: 0.442042 Train_Acc: 0.8906 Val_Acc: 0.6094
# [1500/5850] Loss: 0.273378 Train_Acc: 0.9609 Val_Acc: 0.6406
# [2000/5850] Loss: 0.137227 Train_Acc: 0.9844 Val_Acc: 0.5938
# [2500/5850] Loss: 0.098813 Train_Acc: 1.0000 Val_Acc: 0.6797
# [3000/5850] Loss: 0.175186 Train_Acc: 0.9688 Val_Acc: 0.6172
# [3500/5850] Loss: 0.156554 Train_Acc: 0.9922 Val_Acc: 0.7188
# [4000/5850] Loss: 0.040091 Train_Acc: 1.0000 Val_Acc: 0.6953
# [4500/5850] Loss: 0.006920 Train_Acc: 1.0000 Val_Acc: 0.6406
# [5000/5850] Loss: 0.035340 Train_Acc: 1.0000 Val_Acc: 0.6328
# [5500/5850] Loss: 0.091051 Train_Acc: 1.0000 Val_Acc: 0.6641
# saved path:  ../logs/cifar_CNN_clf.ckpt

# %%
cifar_cnn.accuracy_score(x_test,Y_test)
# Out:
# 0.63531650641025639

# %% [markdown]
# # PGD targeted attacks

# %%
cifar_cnn.targeted_attack(x_test,Y_test,file_name = 'cifar10_adv')
# Out:
# [0/10000] processed
# [100/10000] processed
# [200/10000] processed
# [300/10000] processed
# [400/10000] processed
# [500/10000] processed
# [600/10000] processed
# [700/10000] processed
# [800/10000] processed
# [900/10000] processed
# [1000/10000] processed
# [1100/10000] processed
# [1200/10000] processed
# [1300/10000] processed
# [1400/10000] processed
# [1500/10000] processed
# [1600/10000] processed
# [1700/10000] processed
# [1800/10000] processed
# [1900/10000] processed
# [2000/10000] processed
# [2100/10000] processed
# [2200/10000] processed
# [2300/10000] processed
# [2400/10000] processed
# [2500/10000] processed
# [2600/10000] processed
# [2700/10000] processed
# [2800/10000] processed
# [2900/10000] processed
# [3000/10000] processed
# [3100/10000] processed
# [3200/10000] processed
# [3300/10000] processed
# [3400/10000] processed
# [3500/10000] processed
# [3600/10000] processed
# [3700/10000] processed
# [3800/10000] processed
# [3900/10000] processed
# [4000/10000] processed
# [4100/10000] processed
# [4200/10000] processed
# [4300/10000] processed
# [4400/10000] processed
# [4500/10000] processed
# [4600/10000] processed
# [4700/10000] processed
# [4800/10000] processed
# [4900/10000] processed
# [5000/10000] processed
# [5100/10000] processed
# [5200/10000] processed
# [5300/10000] processed
# [5400/10000] processed
# [5500/10000] processed
# [5600/10000] processed
# [5700/10000] processed
# [5800/10000] processed
# [5900/10000] processed
# [6000/10000] processed
# [6100/10000] processed
# [6200/10000] processed
# [6300/10000] processed
# [6400/10000] processed
# [6500/10000] processed
# [6600/10000] processed
# [6700/10000] processed
# [6800/10000] processed
# [6900/10000] processed
# [7000/10000] processed
# [7100/10000] processed
# [7200/10000] processed
# [7300/10000] processed
# [7400/10000] processed
# [7500/10000] processed
# [7600/10000] processed
# [7700/10000] processed
# [7800/10000] processed
# [7900/10000] processed
# [8000/10000] processed
# [8100/10000] processed
# [8200/10000] processed
# [8300/10000] processed
# [8400/10000] processed
# [8500/10000] processed
# [8600/10000] processed
# [8700/10000] processed
# [8800/10000] processed
# [8900/10000] processed
# [9000/10000] processed
# [9100/10000] processed
# [9200/10000] processed
# [9300/10000] processed
# [9400/10000] processed
# [9500/10000] processed
# [9600/10000] processed
# [9700/10000] processed
# [9800/10000] processed
# [9900/10000] processed

# %% [markdown]
# # Train DAE

# %%
#cifar_dae = Cifar_DAE(x_train,Y_train,noise_scale = 0.1,dae_type = "over",filter_nums = [32,64],
#                      loss_type = "binary_crossentropy",epoch = 10) 
# default is mse nosise!
cifar_dae = Cifar10_DAE(x_train,Y_train,num_epoch=30,loss_type = "mse",num_batch=256)

# %%
cifar_dae.train('../logs/cifar10_tfdae.ckpt',num_viz = 2)
# Out:
# [0/8190] (Loss) Train_n: 0.276763 Train_cln: 0.276702 Val_n: 0.279371 Val_cln: 0.279310
# [500/8190] (Loss) Train_n: 0.230150 Train_cln: 0.229319 Val_n: 0.232282 Val_cln: 0.231442
# [1000/8190] (Loss) Train_n: 0.047673 Train_cln: 0.046891 Val_n: 0.047967 Val_cln: 0.047175
# [1500/8190] (Loss) Train_n: 0.039884 Train_cln: 0.039224 Val_n: 0.040084 Val_cln: 0.039418
# [2000/8190] (Loss) Train_n: 0.035578 Train_cln: 0.034793 Val_n: 0.035743 Val_cln: 0.034951
# [2500/8190] (Loss) Train_n: 0.031484 Train_cln: 0.030565 Val_n: 0.031613 Val_cln: 0.030690
# [3000/8190] (Loss) Train_n: 0.027625 Train_cln: 0.026587 Val_n: 0.027725 Val_cln: 0.026681
# [3500/8190] (Loss) Train_n: 0.024522 Train_cln: 0.023451 Val_n: 0.024598 Val_cln: 0.023520
# [4000/8190] (Loss) Train_n: 0.022008 Train_cln: 0.020919 Val_n: 0.022062 Val_cln: 0.020971
# [4500/8190] (Loss) Train_n: 0.019990 Train_cln: 0.018900 Val_n: 0.020036 Val_cln: 0.018939
# [5000/8190] (Loss) Train_n: 0.018335 Train_cln: 0.017249 Val_n: 0.018367 Val_cln: 0.017280
# [5500/8190] (Loss) Train_n: 0.016966 Train_cln: 0.015887 Val_n: 0.016994 Val_cln: 0.015912
# [6000/8190] (Loss) Train_n: 0.015812 Train_cln: 0.014738 Val_n: 0.015835 Val_cln: 0.014759
# [6500/8190] (Loss) Train_n: 0.014825 Train_cln: 0.013753 Val_n: 0.014845 Val_cln: 0.013771
# [7000/8190] (Loss) Train_n: 0.013969 Train_cln: 0.012900 Val_n: 0.013989 Val_cln: 0.012916
# [7500/8190] (Loss) Train_n: 0.013218 Train_cln: 0.012152 Val_n: 0.013236 Val_cln: 0.012166
# [8000/8190] (Loss) Train_n: 0.012541 Train_cln: 0.011477 Val_n: 0.012557 Val_cln: 0.011491
# saved path:  ../logs/../logs/cifar10_tfdae.ckpt

# %%
recon = cifar_dae.predict(x_train[:1])
plt.figure()
plt.hist(recon[0,:,:,0].flatten())
plt.show()
plt.figure()
plt.hist(recon[0,:,:,1].flatten())
plt.show()
plt.figure()
plt.hist(recon[0,:,:,2].flatten())
plt.show()

# %%
plt.figure()
plt.scatter(x_train[0,:,:,0].flatten(),recon[0,:,:,0].flatten(),color='r')
plt.scatter(x_train[0,:,:,1].flatten(),recon[0,:,:,1].flatten(),color='g')
plt.scatter(x_train[0,:,:,2].flatten(),recon[0,:,:,2].flatten(),color='b')
plt.plot()
plt.show()

# %%
plt.figure()
plt.hist(x_train[0,:,:,0].flatten())
plt.show()
plt.figure()
plt.hist(x_train[0,:,:,1].flatten())
plt.show()
plt.figure()
plt.hist(x_train[0,:,:,2].flatten())
plt.show()

# %%
cifar_dae.plot_imgs(x_train[:20],noise_type = 'gaussian',noise_scale = 0.0)

# %%
cifar_dae.plot_imgs(x_train[:20],noise_type = 'gaussian',noise_scale = 0.0)

# %%
_,x_noisy = corrupt(x_test,scale = 0.1, noise_type = "peppSalt")
cifar_cnn.accuracy_score(x_noisy,Y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-b33f4e4ab20e> in <module>()
#       1 _,x_noisy = corrupt(x_test,scale = 0.1, noise_type = "peppSalt")
# ----> 2 cifar_cnn.accuracy_score(x_noisy,Y_test)
#
# NameError: name 'cifar_cnn' is not defined

# %%
x_dae = cifar_dae.autoencoder.predict(x_noisy)

# %%
print(cifar_cnn.accuracy_score(x_dae,Y_test))
x_dae_c = cifar_dae.autoencoder.predict(x_test)
print(cifar_cnn.accuracy_score(x_dae_c,Y_test))
# Out:
# 0.547676282051
# 0.58343349359

# %%
x_ds = cifar_dae.apply_DS(x_noisy)

# %%
print(cifar_cnn.accuracy_score(x_ds,Y_test))
# Out:
# 0.463741987179

# %%
cifar_dae.plot_imgs(x_ds,noise_type = 'peppSalt',noise_scale = 0.0)
